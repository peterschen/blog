# %% [markdown]
# ## Create table in BigQuery

# %%
# %%bigquery --use_rest_api
# CREATE OR REPLACE TABLE lics.prices_azure (
#     currencyCode STRING,
#     retailPrice FLOAT64,
#     unitPrice FLOAT64,
#     armRegionName STRING,
#     meterId STRING,
#     meterName STRING,
#     skuName STRING,
#     productName STRING,
#     serviceFamily STRING,
#     unitOfMeasure STRING,
#     type STRING,
#     armSkuName STRING,
#     licensePrice FLOAT64
# );
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Create view

# %%
# %%bigquery --use_rest_api
# CREATE OR REPLACE VIEW lics.v_prices_azure
# AS
#     SELECT armRegionName, meterName, productName, licensePrice, licensePrice / Cores AS licensePriceCore
#     FROM (
#         SELECT *,
#             CASE
#                 WHEN armSkuName = 'Basic_A0' THEN 1
#                 WHEN armSkuName = 'Basic_A1' THEN 1
#                 WHEN armSkuName = 'Basic_A2' THEN 2
#                 WHEN armSkuName = 'Basic_A3' THEN 4
#                 WHEN armSkuName = 'Basic_A4' THEN 8
#                 WHEN armSkuName = 'Standard_A0' THEN 1
#                 WHEN armSkuName = 'Standard_A1' THEN 1
#                 WHEN armSkuName = 'Standard_A2' THEN 2
#                 WHEN armSkuName = 'Standard_A3' THEN 4
#                 WHEN armSkuName = 'Standard_A4' THEN 8
#                 WHEN armSkuName = 'Standard_A5' THEN 2
#                 WHEN armSkuName = 'Standard_A6' THEN 4
#                 WHEN armSkuName = 'Standard_A7' THEN 8
#                 WHEN armSkuName = 'Standard_A8' THEN 8
#                 WHEN armSkuName = 'Standard_A9' THEN 16
#                 WHEN armSkuName = 'Standard_A10' THEN 8
#                 WHEN armSkuName = 'Standard_A11' THEN 16
#                 WHEN armSkuName = 'Standard_D1' THEN 1
#                 WHEN armSkuName = 'Standard_D2' THEN 2
#                 WHEN armSkuName = 'Standard_D3' THEN 4
#                 WHEN armSkuName = 'Standard_D4' THEN 8
#                 WHEN armSkuName = 'Standard_D11' THEN 2
#                 WHEN armSkuName = 'Standard_D12' THEN 4
#                 WHEN armSkuName = 'Standard_D13' THEN 8
#                 WHEN armSkuName = 'Standard_D14' THEN 16
#                 WHEN armSkuName = 'Standard_DS1' THEN 1
#                 WHEN armSkuName = 'Standard_DS2' THEN 2
#                 WHEN armSkuName = 'Standard_DS3' THEN 4
#                 WHEN armSkuName = 'Standard_DS4' THEN 8
#                 WHEN armSkuName = 'Standard_DS11' THEN 2
#                 WHEN armSkuName = 'Standard_DS12' THEN 4
#                 WHEN armSkuName = 'Standard_DS13' THEN 8
#                 WHEN armSkuName = 'Standard_DS14' THEN 16
#                 WHEN armSkuName = 'Standard_GS1' THEN 2
#                 WHEN armSkuName = 'Standard_GS2' THEN 4
#                 WHEN armSkuName = 'Standard_GS3' THEN 8
#                 WHEN armSkuName = 'Standard_GS4' THEN 16
#                 WHEN armSkuName = 'Standard_GS5' THEN 32
#                 WHEN armSkuName = 'Standard_G1' THEN 2
#                 WHEN armSkuName = 'Standard_G2' THEN 4
#                 WHEN armSkuName = 'Standard_G3' THEN 8
#                 WHEN armSkuName = 'Standard_G4' THEN 16
#                 WHEN armSkuName = 'Standard_G5' THEN 32
#                 ELSE CAST(REGEXP_EXTRACT(meterName, r'^[a-zA-Z]+([0-9]+)') AS INT64)
#             END AS Cores
#         FROM lics.prices_azure
#     )
# ;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Query Azure Retail Prices API
# More information in the [](https://docs.microsoft.com/en-us/rest/api/cost-management/retail-prices/azure-retail-prices).

# %%
import requests
import json
from google.cloud import bigquery

def getPrices(region, filterExpression = None):
    uri = f"https://prices.azure.com/api/retail/prices?$filter=serviceName eq 'Virtual Machines'"
    uri += f" and armRegionName eq '{region}'"
    uri += f" and indexof(meterName, 'Spot') eq -1"
    uri += f" and indexof(meterName, 'Low Priority') eq -1"
    uri += f" and indexof(armSkuName, 'Promo') eq -1"
    
    if filterExpression is not None:
        uri += f" {filterExpression}"
    
    return invokePriceApi(uri)
    
def invokePriceApi(uri):
    result = requests.get(uri)
    
    if result.status_code == 200:
        data = result.json()
        items = data["Items"]
        count = data["Count"]
        nextPageLink = data["NextPageLink"]
        
        while nextPageLink is not None:
            result = requests.get(nextPageLink)
            data = result.json()
            items.extend(data["Items"])
            nextPageLink = data["NextPageLink"]
        
        return items

def getWindowsSkus(region):
    return getPrices(region, "and contains(ProductName, 'Windows')")
    
def getConsumptionPrice(items):
    for item in items:
        if item["type"] == "Consumption":
            return item["unitPrice"]
        
    return None

# Initiate BigQuery
bq = bigquery.Client()
region = "westeurope"

windowsSkus = getWindowsSkus(region)

if len(windowsSkus) > 0:
    query = "INSERT INTO lics.prices_azure (currencyCode, retailPrice, unitPrice, armRegionName, meterId, meterName, skuName, productName, serviceFamily, unitOfMeasure, type, armSkuName, licensePrice) VALUES "
    values = ""

    for item in windowsSkus:
        meterName = item["meterName"]
        
        if item["type"] == 'Consumption':
            skuId = item["skuId"]
            currencyCode = item["currencyCode"]
            retailPrice = item["retailPrice"]
            unitPrice = item["unitPrice"]
            armRegionName = item["armRegionName"]
            meterId = item["meterId"]
            skuName = item["skuName"]
            productName = item["productName"]
            serviceFamily = item["serviceFamily"]
            unitOfMeasure = item["unitOfMeasure"]
            meterType = item["type"]
            armSkuName = item["armSkuName"]
            
            rawSkus = getPrices(region, f"and meterName eq '{meterName}' and indexof(productName, 'Windows') eq -1")
            rawPrice = getConsumptionPrice(rawSkus)
            
            if rawPrice is None:
                print(f"Unit price without Windows license could not be retrieved ({productName} - {meterName})")
                continue
            
            licensePrice = unitPrice - rawPrice
            
            print(f"{meterName} - {armSkuName}: {licensePrice} / excl. lics: {rawPrice} / incl. lics: {unitPrice}")
            
            if len(values) > 0:
                values += ", "
            
            values += f"('{currencyCode}', {retailPrice}, {unitPrice}, '{armRegionName}', '{meterId}', '{meterName}', '{skuName}', '{productName}', '{serviceFamily}', '{unitOfMeasure}', '{meterType}', '{armSkuName}', {licensePrice})"
            
    query += values
    bq.query(query).result()
else:
    print(f"Empty list for {region}")
# Out:
# F2s - Standard_F2s: 0.09199999999999998 / excl. lics: 0.114 / incl. lics: 0.206
# F2/F2s - Standard_F2: 0.09199999999999998 / excl. lics: 0.114 / incl. lics: 0.206
# E48 v3/E48s v3 - Standard_E48_v3: 2.2080000000000006 / excl. lics: 3.647 / incl. lics: 5.855
# E48s v3 - Standard_E48s_v3: 2.2080000000000006 / excl. lics: 3.647 / incl. lics: 5.855
# F4/F4s - Standard_F4: 0.18399999999999997 / excl. lics: 0.227 / incl. lics: 0.411
# F4s - Standard_F4s: 0.18399999999999997 / excl. lics: 0.227 / incl. lics: 0.411
# L32s - Standard_L32s: 1.4720000000000004 / excl. lics: 2.976 / incl. lics: 4.448
# NC6 - Standard_NC6: 0.22100000000000009 / excl. lics: 1.166 / incl. lics: 1.387
# D32a v4/D32as v4 - Standard_D32a_v4: 1.4719999999999998 / excl. lics: 1.84 / incl. lics: 3.312
# D32as v4 - Standard_D32as_v4: 1.4719999999999998 / excl. lics: 1.84 / incl. lics: 3.312
# G3/GS3 - Standard_G3: 0.28000000000000025 / excl. lics: 2.8 / incl. lics: 3.08
# GS3 - Standard_GS3: 0.28000000000000025 / excl. lics: 2.8 / incl. lics: 3.08
# DS3 - Standard_DS3: 0.25699999999999995 / excl. lics: 0.336 / incl. lics: 0.593
# D3/DS3 - Standard_D3: 0.25699999999999995 / excl. lics: 0.336 / incl. lics: 0.593
# HC44-16rs - Standard_HC44-16rs: 2.024 / excl. lics: 4.118 / incl. lics: 6.142
# H8m - Standard_H8m: 0.9020000000000001 / excl. lics: 1.383 / incl. lics: 2.285
# D4as v4 - Standard_D4as_v4: 0.18399999999999997 / excl. lics: 0.23 / incl. lics: 0.414
# D4a v4/D4as v4 - Standard_D4a_v4: 0.18399999999999997 / excl. lics: 0.23 / incl. lics: 0.414
# NC24s v2 - Standard_NC24s_v2: 2.0310000000000006 / excl. lics: 10.728 / incl. lics: 12.759
# ND6s - Standard_ND6s: 0.508 / excl. lics: 2.682 / incl. lics: 3.19
# E48ds v4 - Standard_E48ds_v4: 2.208 / excl. lics: 4.152 / incl. lics: 6.36
# E32-16s v4 - Standard_E32-16s_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# E20a v4/E20as v4 - Standard_E20a_v4: 0.9199999999999999 / excl. lics: 1.52 / incl. lics: 2.44
# E20as v4 - Standard_E20as_v4: 0.9199999999999999 / excl. lics: 1.52 / incl. lics: 2.44
# A9 - Standard_A9: 0.8620000000000001 / excl. lics: 2.243 / incl. lics: 3.105
# H16 - Standard_H16: 1.346 / excl. lics: 2.065 / incl. lics: 3.411
# M128m - : 9.125999999999998 / excl. lics: 37.3632 / incl. lics: 46.4892
# E32s v4 - Standard_E32s_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# M16-8ms - Standard_M16-8ms: 1.1407999999999996 / excl. lics: 4.3022 / incl. lics: 5.443
# M16-4ms - Standard_M16-4ms: 1.1407999999999996 / excl. lics: 4.3022 / incl. lics: 5.443
# M16ms - Standard_M16ms: 1.1407999999999996 / excl. lics: 4.3022 / incl. lics: 5.443
# A2 - Standard_A2: 0.06 / excl. lics: 0.12 / incl. lics: 0.18
# HB60-45rs - Standard_HB60-45rs: 2.7600000000000002 / excl. lics: 2.964 / incl. lics: 5.724
# NC6s v2 - Standard_NC6s_v2: 0.508 / excl. lics: 2.682 / incl. lics: 3.19
# A3 - Standard_A3: 0.156 / excl. lics: 0.204 / incl. lics: 0.36
# H8 - Standard_H8: 0.6739999999999999 / excl. lics: 1.032 / incl. lics: 1.706
# DC4s - Standard_DC4s: 0.09199999999999997 / excl. lics: 0.514 / incl. lics: 0.606
# NC24r - Standard_NC24r: 0.9720000000000004 / excl. lics: 5.132 / incl. lics: 6.104
# E2 v4 - Standard_E2_v4: 0.092 / excl. lics: 0.152 / incl. lics: 0.244
# D4 v2/DS4 v2 - Standard_D4_v2: 0.522 / excl. lics: 0.544 / incl. lics: 1.066
# DS4 v2 - Standard_DS4_v2: 0.522 / excl. lics: 0.544 / incl. lics: 1.066
# HB60rs - Standard_HB60rs: 2.7600000000000002 / excl. lics: 2.964 / incl. lics: 5.724
# NC24rs v3 - Standard_NC24rs_v3: 1.2149999999999999 / excl. lics: 16.821 / incl. lics: 18.036
# E64-32s v3 - Standard_E64-32s_v3: 2.944 / excl. lics: 4.376 / incl. lics: 7.32
# E64s v3 - Standard_E64s_v3: 2.944 / excl. lics: 4.376 / incl. lics: 7.32
# E64-16s v3 - Standard_E64-16s_v3: 2.944 / excl. lics: 4.376 / incl. lics: 7.32
# E64 v3/E64s v3 - Standard_E64_v3: 2.944 / excl. lics: 4.376 / incl. lics: 7.32
# DS14 v2 - Standard_DS14_v2: 0.7100000000000002 / excl. lics: 1.518 / incl. lics: 2.228
# D14 v2/DS14 v2 - Standard_D14_v2: 0.7100000000000002 / excl. lics: 1.518 / incl. lics: 2.228
# Unit price without Windows license could not be retrieved (Virtual Machines DSv2 Series Windows - DS14-4 v2)
# Unit price without Windows license could not be retrieved (Virtual Machines DSv2 Series Windows - DS14-8 v2)
# A1 - Standard_A1: 0.063 / excl. lics: 0.027 / incl. lics: 0.09
# E2as v4 - Standard_E2as_v4: 0.092 / excl. lics: 0.152 / incl. lics: 0.244
# E2a v4/E2as v4 - Standard_E2a_v4: 0.092 / excl. lics: 0.152 / incl. lics: 0.244
# ND24s - Standard_ND24s: 2.032 / excl. lics: 10.727 / incl. lics: 12.759
# M192ims_v2 - Standard_M192ims_v2: 8.832 / excl. lics: 44.3 / incl. lics: 53.132
# M208-104ms_v2 - Standard_M208-104ms_v2: 9.568000000000005 / excl. lics: 53.544 / incl. lics: 63.112
# M208-52ms_v2 - Standard_M208-52ms_v2: 9.568000000000005 / excl. lics: 53.544 / incl. lics: 63.112
# M208ms v2 - Standard_M208ms_v2: 9.568000000000005 / excl. lics: 53.544 / incl. lics: 63.112
# NP20s - Standard_NP20s: 0.45999999999999996 / excl. lics: 2.6 / incl. lics: 3.06
# F16s v2 - Standard_F16s_v2: 0.7050000000000001 / excl. lics: 0.776 / incl. lics: 1.481
# NC12 - Standard_NC12: 0.44099999999999984 / excl. lics: 2.333 / incl. lics: 2.774
# E48 v4 - Standard_E48_v4: 2.2079999999999997 / excl. lics: 3.648 / incl. lics: 5.856
# D48s v4 - Standard_D48s_v4: 2.208 / excl. lics: 2.76 / incl. lics: 4.968
# E80ids v4 - Standard_E80ids_v4: 3.6799999999999997 / excl. lics: 6.92 / incl. lics: 10.6
# DS11 v2 - Standard_DS11_v2: 0.08900000000000002 / excl. lics: 0.19 / incl. lics: 0.279
# Unit price without Windows license could not be retrieved (Virtual Machines DSv2 Series Windows - DS11-1 v2)
# D11 v2/DS11 v2 - Standard_D11_v2: 0.08900000000000002 / excl. lics: 0.19 / incl. lics: 0.279
# F64s v2 - Standard_F64s_v2: 2.8179999999999996 / excl. lics: 3.104 / incl. lics: 5.922
# E4d v4 - Standard_E4d_v4: 0.18400000000000005 / excl. lics: 0.346 / incl. lics: 0.53
# A3 - Basic_A3: 0.12000000000000002 / excl. lics: 0.204 / incl. lics: 0.324
# D48d v4 - Standard_D48d_v4: 2.2080000000000006 / excl. lics: 3.264 / incl. lics: 5.472
# NV6 - Standard_NV6: 0.22999999999999998 / excl. lics: 1.365 / incl. lics: 1.595
# D4 v4 - Standard_D4_v4: 0.18399999999999997 / excl. lics: 0.23 / incl. lics: 0.414
# E8d v4 - Standard_E8d_v4: 0.3680000000000001 / excl. lics: 0.692 / incl. lics: 1.06
# D4d v4 - Standard_D4d_v4: 0.184 / excl. lics: 0.272 / incl. lics: 0.456
# E32ds v4 - Standard_E32ds_v4: 1.4720000000000004 / excl. lics: 2.768 / incl. lics: 4.24
# E16s v4 - Standard_E16s_v4: 0.736 / excl. lics: 1.216 / incl. lics: 1.952
# D12/DS12 - Standard_D12: 0.11700000000000005 / excl. lics: 0.442 / incl. lics: 0.559
# DS12 - Standard_DS12: 0.11700000000000005 / excl. lics: 0.442 / incl. lics: 0.559
# D48 v4 - Standard_D48_v4: 2.208 / excl. lics: 2.76 / incl. lics: 4.968
# D16as v4 - Standard_D16as_v4: 0.7359999999999999 / excl. lics: 0.92 / incl. lics: 1.656
# D16a v4/D16as v4 - Standard_D16a_v4: 0.7359999999999999 / excl. lics: 0.92 / incl. lics: 1.656
# D32d v4 - Standard_D32d_v4: 1.472 / excl. lics: 2.176 / incl. lics: 3.648
# E8-4s v4 - Standard_E8-4s_v4: 0.368 / excl. lics: 0.608 / incl. lics: 0.976
# E2s v4 - Standard_E2s_v4: 0.092 / excl. lics: 0.152 / incl. lics: 0.244
# E20d v4 - Standard_E20d_v4: 0.9199999999999999 / excl. lics: 1.73 / incl. lics: 2.65
# D13 v2/DS13 v2 - Standard_D13_v2: 0.3550000000000001 / excl. lics: 0.759 / incl. lics: 1.114
# Unit price without Windows license could not be retrieved (Virtual Machines DSv2 Series Windows - DS13-4 v2)
# DS13 v2 - Standard_DS13_v2: 0.3550000000000001 / excl. lics: 0.759 / incl. lics: 1.114
# Unit price without Windows license could not be retrieved (Virtual Machines DSv2 Series Windows - DS13-2 v2)
# NV24s v3 - Standard_NV24s_v3: 1.104 / excl. lics: 2.85 / incl. lics: 3.954
# E96a v4/E96as v4 - Standard_E96a_v4: 4.4159999999999995 / excl. lics: 7.296 / incl. lics: 11.712
# E96as v4 - Standard_E96as_v4: 4.4159999999999995 / excl. lics: 7.296 / incl. lics: 11.712
# M64s - Standard_M64s: 2.944000000000001 / excl. lics: 9.337 / incl. lics: 12.281
# D8 v4 - Standard_D8_v4: 0.36799999999999994 / excl. lics: 0.46 / incl. lics: 0.828
# D16d v4 - Standard_D16d_v4: 0.736 / excl. lics: 1.088 / incl. lics: 1.824
# B2ms - Standard_B2ms: 0.007999999999999993 / excl. lics: 0.096 / incl. lics: 0.104
# A4 - Standard_A4: 0.24 / excl. lics: 0.48 / incl. lics: 0.72
# D2a v4/D2as v4 - Standard_D2a_v4: 0.09199999999999998 / excl. lics: 0.115 / incl. lics: 0.207
# D2as v4 - Standard_D2as_v4: 0.09199999999999998 / excl. lics: 0.115 / incl. lics: 0.207
# A0 - Standard_A0: 0.0020000000000000018 / excl. lics: 0.018 / incl. lics: 0.02
# M128dms_v2 - M128dms_v2: 5.887999999999998 / excl. lics: 37.366 / incl. lics: 43.254
# F2s v2 - Standard_F2s_v2: 0.088 / excl. lics: 0.097 / incl. lics: 0.185
# HB60-30rs - Standard_HB60-30rs: 2.7600000000000002 / excl. lics: 2.964 / incl. lics: 5.724
# HC44-32rs - Standard_HC44-32rs: 2.024 / excl. lics: 4.118 / incl. lics: 6.142
# D96a v4/D96as v4 - Standard_D96a_v4: 4.416 / excl. lics: 5.52 / incl. lics: 9.936
# D96as v4 - Standard_D96as_v4: 4.416 / excl. lics: 5.52 / incl. lics: 9.936
# B1ms - Standard_B1ms: 0.0036999999999999984 / excl. lics: 0.024 / incl. lics: 0.0277
# D2/DS2 - Standard_D2: 0.12899999999999998 / excl. lics: 0.168 / incl. lics: 0.297
# DS2 - Standard_DS2: 0.12899999999999998 / excl. lics: 0.168 / incl. lics: 0.297
# M64dms_v2 - M64dms_v2: 2.944000000000001 / excl. lics: 14.476 / incl. lics: 17.42
# DS1 v2 - Standard_DS1_v2: 0.0651 / excl. lics: 0.0679 / incl. lics: 0.133
# D1 v2/DS1 v2 - Standard_D1_v2: 0.0651 / excl. lics: 0.0679 / incl. lics: 0.133
# B1s - Standard_B1s: 0.004 / excl. lics: 0.012 / incl. lics: 0.016
# E4 v3/E4s v3 - Standard_E4_v3: 0.184 / excl. lics: 0.32 / incl. lics: 0.504
# E4-2s v3 - Standard_E4-2s_v3: 0.184 / excl. lics: 0.32 / incl. lics: 0.504
# E4s v3 - Standard_E4s_v3: 0.184 / excl. lics: 0.32 / incl. lics: 0.504
# E32-8ds v4 - Standard_E32-8ds_v4: 1.4720000000000004 / excl. lics: 2.768 / incl. lics: 4.24
# DC2s v2 - Standard_DC2s_v2: 0.09199999999999997 / excl. lics: 0.514 / incl. lics: 0.606
# NC12s v3 - Standard_NC12s_v3: 0.5520000000000005 / excl. lics: 7.646 / incl. lics: 8.198
# L32s v2 - Standard_L32s_v2: 1.4720000000000004 / excl. lics: 2.976 / incl. lics: 4.448
# E4-2ds v4 - Standard_E4-2ds_v4: 0.18400000000000005 / excl. lics: 0.346 / incl. lics: 0.53
# ND96asr v4 - Standard_ND96asr_v4: 4.416000000000004 / excl. lics: 35.357 / incl. lics: 39.773
# A6 - Standard_A6: 0.14 / excl. lics: 0.54 / incl. lics: 0.68
# E48as v4 - Standard_E48as_v4: 2.2079999999999997 / excl. lics: 3.648 / incl. lics: 5.856
# E48a v4/E48as v4 - Standard_E48a_v4: 2.2079999999999997 / excl. lics: 3.648 / incl. lics: 5.856
# E32a v4/E32as v4 - Standard_E32a_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# E32as v4 - Standard_E32as_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# L48s v2 - Standard_L48s_v2: 2.2079999999999993 / excl. lics: 4.464 / incl. lics: 6.672
# NC4as T4 v3 - Standard_NC4as_T4_v3: 0.18399999999999994 / excl. lics: 0.658 / incl. lics: 0.842
# GS4 - Standard_GS4: 0.5600000000000005 / excl. lics: 5.6 / incl. lics: 6.16
# GS4-4 - Standard_GS4-4: 0.5600000000000005 / excl. lics: 5.6 / incl. lics: 6.16
# GS4-8 - Standard_GS4-8: 0.5600000000000005 / excl. lics: 5.6 / incl. lics: 6.16
# G4/GS4 - Standard_G4: 0.5600000000000005 / excl. lics: 5.6 / incl. lics: 6.16
# M128ms_v2 - Standard_M128ms_v2: 5.887999999999998 / excl. lics: 36.777 / incl. lics: 42.665
# D4 v3/D4s v3 - Standard_D4_v3: 0.184 / excl. lics: 0.24 / incl. lics: 0.424
# D4s v3 - Standard_D4s_v3: 0.184 / excl. lics: 0.24 / incl. lics: 0.424
# D4ds v4 - Standard_D4ds_v4: 0.184 / excl. lics: 0.272 / incl. lics: 0.456
# D4s v4 - Standard_D4s_v4: 0.18399999999999997 / excl. lics: 0.23 / incl. lics: 0.414
# ND12s - Standard_ND12s: 1.0169999999999995 / excl. lics: 5.363 / incl. lics: 6.38
# DS11 - Standard_DS11: 0.058000000000000024 / excl. lics: 0.221 / incl. lics: 0.279
# D11/DS11 - Standard_D11: 0.058000000000000024 / excl. lics: 0.221 / incl. lics: 0.279
# H16mr - Standard_H16mr: 1.984 / excl. lics: 3.043 / incl. lics: 5.027
# D32s v4 - Standard_D32s_v4: 1.4719999999999998 / excl. lics: 1.84 / incl. lics: 3.312
# L80s v2 - Standard_L80s_v2: 3.679999999999999 / excl. lics: 7.44 / incl. lics: 11.12
# E32d v4 - Standard_E32d_v4: 1.4720000000000004 / excl. lics: 2.768 / incl. lics: 4.24
# E8ds v4 - Standard_E8ds_v4: 0.3680000000000001 / excl. lics: 0.692 / incl. lics: 1.06
# E48d v4 - Standard_E48d_v4: 2.208 / excl. lics: 4.152 / incl. lics: 6.36
# E16 v4 - Standard_E16_v4: 0.736 / excl. lics: 1.216 / incl. lics: 1.952
# M416is v2 - Standard_M416is_v2: 19.136000000000003 / excl. lics: 59.496 / incl. lics: 78.632
# A0 - Basic_A0: 0.0 / excl. lics: 0.018 / incl. lics: 0.018
# E64 v4 - Standard_E64_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# DS14 - Standard_DS14: 0.4670000000000003 / excl. lics: 1.769 / incl. lics: 2.236
# D14/DS14 - Standard_D14: 0.4670000000000003 / excl. lics: 1.769 / incl. lics: 2.236
# D32 v4 - Standard_D32_v4: 1.4719999999999998 / excl. lics: 1.84 / incl. lics: 3.312
# D32-8s v3 - Standard_D32-8s_v3: 1.472 / excl. lics: 1.92 / incl. lics: 3.392
# D32s v3 - Standard_D32s_v3: 1.472 / excl. lics: 1.92 / incl. lics: 3.392
# D32-16s v3 - Standard_D32-16s_v3: 1.472 / excl. lics: 1.92 / incl. lics: 3.392
# D32 v3/D32s v3 - Standard_D32_v3: 1.472 / excl. lics: 1.92 / incl. lics: 3.392
# D64d v4 - Standard_D64d_v4: 2.944 / excl. lics: 4.352 / incl. lics: 7.296
# D48 v3/D48s v3 - Standard_D48_v3: 2.208 / excl. lics: 2.88 / incl. lics: 5.088
# D48s v3 - Standard_D48s_v3: 2.208 / excl. lics: 2.88 / incl. lics: 5.088
# D15 v2/DS15 v2 - Standard_D15_v2: 0.8880000000000001 / excl. lics: 1.897 / incl. lics: 2.785
# DS15 v2 - Standard_DS15_v2: 0.8880000000000001 / excl. lics: 1.897 / incl. lics: 2.785
# D32ds v4 - Standard_D32ds_v4: 1.472 / excl. lics: 2.176 / incl. lics: 3.648
# D16s v4 - Standard_D16s_v4: 0.7359999999999999 / excl. lics: 0.92 / incl. lics: 1.656
# E32-16ds v4 - Standard_E32-16ds_v4: 1.4720000000000004 / excl. lics: 2.768 / incl. lics: 4.24
# NV24 - Standard_NV24: 0.9199999999999999 / excl. lics: 5.46 / incl. lics: 6.38
# NC12s v2 - Standard_NC12s_v2: 1.016 / excl. lics: 5.364 / incl. lics: 6.38
# M192ids_v2 - M192ids_v2: 8.831 / excl. lics: 22.445 / incl. lics: 31.276
# L88is v2 - Standard_L88is_v2: 4.048 / excl. lics: 8.184 / incl. lics: 12.232
# D15i v2/DS15i v2 - Standard_D15i_v2: 0.8880000000000001 / excl. lics: 1.897 / incl. lics: 2.785
# DS15i v2 - Standard_DS15i_v2: 0.8880000000000001 / excl. lics: 1.897 / incl. lics: 2.785
# E96-24as_v4 - Standard_E96-24as_v4: 4.4159999999999995 / excl. lics: 7.296 / incl. lics: 11.712
# NV8as v4 - Standard_NV8as_v4: 0.368 / excl. lics: 0.582 / incl. lics: 0.95
# E32 v4 - Standard_E32_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# E32-8s v4 - Standard_E32-8s_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# NC8as T4 v3 - Standard_NC8as_T4_v3: 0.3680000000000001 / excl. lics: 0.94 / incl. lics: 1.308
# Unit price without Windows license could not be retrieved (Virtual Machines DSv2 Series Windows - DS12-1 v2)
# DS12 v2 - Standard_DS12_v2: 0.17800000000000005 / excl. lics: 0.379 / incl. lics: 0.557
# D12 v2/DS12 v2 - Standard_D12_v2: 0.17800000000000005 / excl. lics: 0.379 / incl. lics: 0.557
# A11 - Standard_A11: 0.69 / excl. lics: 1.794 / incl. lics: 2.484
# M416ms v2 - Standard_M416ms_v2: 19.13600000000001 / excl. lics: 118.98 / incl. lics: 138.116
# M416-208ms_v2 - Standard_M416-208ms_v2: 19.13600000000001 / excl. lics: 118.98 / incl. lics: 138.116
# M416-104ms_v2 - Standard_M416-104ms_v2: 19.13600000000001 / excl. lics: 118.98 / incl. lics: 138.116
# E16-4ds v4 - Standard_E16-4ds_v4: 0.7360000000000002 / excl. lics: 1.384 / incl. lics: 2.12
# H16m - Standard_H16m: 1.8030000000000004 / excl. lics: 2.767 / incl. lics: 4.57
# E64d v4 - Standard_E64d_v4: 2.944000000000001 / excl. lics: 5.536 / incl. lics: 8.48
# NV12 - Standard_NV12: 0.45999999999999996 / excl. lics: 2.73 / incl. lics: 3.19
# D2s v4 - Standard_D2s_v4: 0.09199999999999998 / excl. lics: 0.115 / incl. lics: 0.207
# D64as v4 - Standard_D64as_v4: 2.9439999999999995 / excl. lics: 3.68 / incl. lics: 6.624
# D64a v4/D64as v4 - Standard_D64a_v4: 2.9439999999999995 / excl. lics: 3.68 / incl. lics: 6.624
# E32-8as_v4 - Standard_E32-8as_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# NC24s v3 - Standard_NC24s_v3: 1.104000000000001 / excl. lics: 15.292 / incl. lics: 16.396
# HB120-32rs_v3 - Standard_HB120-32rs_v3: 5.52 / excl. lics: 4.68 / incl. lics: 10.2
# HB120-96rs_v3 - Standard_HB120-96rs_v3: 5.52 / excl. lics: 4.68 / incl. lics: 10.2
# HB120rs_v3 - Standard_HB120rs_v3: 5.52 / excl. lics: 4.68 / incl. lics: 10.2
# HB120-64rs_v3 - Standard_HB120-64rs_v3: 5.52 / excl. lics: 4.68 / incl. lics: 10.2
# HB120-16rs_v3 - Standard_HB120-16rs_v3: 5.52 / excl. lics: 4.68 / incl. lics: 10.2
# D2ds v4 - Standard_D2ds_v4: 0.092 / excl. lics: 0.136 / incl. lics: 0.228
# F48s v2 - Standard_F48s_v2: 2.209 / excl. lics: 2.328 / incl. lics: 4.537
# A4 - Basic_A4: 0.16800000000000004 / excl. lics: 0.48 / incl. lics: 0.648
# E16-4s v4 - Standard_E16-4s_v4: 0.736 / excl. lics: 1.216 / incl. lics: 1.952
# E20 v4 - Standard_E20_v4: 0.9199999999999999 / excl. lics: 1.52 / incl. lics: 2.44
# HC44rs - Standard_HC44rs: 2.024 / excl. lics: 4.118 / incl. lics: 6.142
# DC1s v2 - Standard_DC1s_v2: 0.045999999999999985 / excl. lics: 0.257 / incl. lics: 0.303
# A2 - Basic_A2: 0.0010000000000000009 / excl. lics: 0.12 / incl. lics: 0.121
# D16 v3/D16s v3 - Standard_D16_v3: 0.736 / excl. lics: 0.96 / incl. lics: 1.696
# D16s v3 - Standard_D16s_v3: 0.736 / excl. lics: 0.96 / incl. lics: 1.696
# E20ds v4 - Standard_E20ds_v4: 0.9199999999999999 / excl. lics: 1.73 / incl. lics: 2.65
# D8a v4/D8as v4 - Standard_D8a_v4: 0.36799999999999994 / excl. lics: 0.46 / incl. lics: 0.828
# D8as v4 - Standard_D8as_v4: 0.36799999999999994 / excl. lics: 0.46 / incl. lics: 0.828
# E8-4s v3 - Standard_E8-4s_v3: 0.368 / excl. lics: 0.64 / incl. lics: 1.008
# E8-2s v3 - Standard_E8-2s_v3: 0.368 / excl. lics: 0.64 / incl. lics: 1.008
# E8s v3 - Standard_E8s_v3: 0.368 / excl. lics: 0.64 / incl. lics: 1.008
# E8 v3/E8s v3 - Standard_E8_v3: 0.368 / excl. lics: 0.64 / incl. lics: 1.008
# NC24 - Standard_NC24: 0.883 / excl. lics: 4.666 / incl. lics: 5.549
# A8 - Standard_A8: 0.43199999999999994 / excl. lics: 1.121 / incl. lics: 1.553
# M128s - Standard_M128s: 5.889000000000003 / excl. lics: 18.673 / incl. lics: 24.562
# E4ds v4 - Standard_E4ds_v4: 0.18400000000000005 / excl. lics: 0.346 / incl. lics: 0.53
# E8s v4 - Standard_E8s_v4: 0.368 / excl. lics: 0.608 / incl. lics: 0.976
# NV12s v3 - Standard_NV12s_v3: 0.552 / excl. lics: 1.426 / incl. lics: 1.978
# NV4as v4 - Standard_NV4as_v4: 0.184 / excl. lics: 0.291 / incl. lics: 0.475
# M32ms - Standard_M32ms: 2.281599999999999 / excl. lics: 8.6044 / incl. lics: 10.886
# M32-16ms - Standard_M32-16ms: 2.281599999999999 / excl. lics: 8.6044 / incl. lics: 10.886
# M32-8ms - Standard_M32-8ms: 2.281599999999999 / excl. lics: 8.6044 / incl. lics: 10.886
# A2m v2 - Standard_A2m_v2: 0.064 / excl. lics: 0.124 / incl. lics: 0.188
# H16r - Standard_H16r: 1.4809999999999999 / excl. lics: 2.271 / incl. lics: 3.752
# L64s v2 - Standard_L64s_v2: 2.944000000000001 / excl. lics: 5.952 / incl. lics: 8.896
# D8ds v4 - Standard_D8ds_v4: 0.368 / excl. lics: 0.544 / incl. lics: 0.912
# F8/F8s - Standard_F8: 0.36799999999999994 / excl. lics: 0.454 / incl. lics: 0.822
# F8s - Standard_F8s: 0.36799999999999994 / excl. lics: 0.454 / incl. lics: 0.822
# NC6s v3 - Standard_NC6s_v3: 0.27600000000000025 / excl. lics: 3.823 / incl. lics: 4.099
# B4ms - Standard_B4ms: 0.015999999999999986 / excl. lics: 0.192 / incl. lics: 0.208
# M32ls - Standard_M32ls: 1.4613999999999998 / excl. lics: 3.4476 / incl. lics: 4.909
# L8s - Standard_L8s: 0.3680000000000001 / excl. lics: 0.744 / incl. lics: 1.112
# E32-16as_v4 - Standard_E32-16as_v4: 1.472 / excl. lics: 2.432 / incl. lics: 3.904
# ND24rs - Standard_ND24rs: 2.2349999999999994 / excl. lics: 11.804 / incl. lics: 14.039
# NP40s - Standard_NP40s: 0.9199999999999999 / excl. lics: 5.2 / incl. lics: 6.12
# PB12s - Standard_PB12s: 0.718 / excl. lics: 2.158 / incl. lics: 2.876
# E64-32as_v4 - Standard_E64-32as_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# E64-16s v4 - Standard_E64-16s_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# M128s_v2 - Standard_M128s_v2: 5.888000000000002 / excl. lics: 18.087 / incl. lics: 23.975
# M16s - Standard_M16s: 0.7359999999999998 / excl. lics: 3.3418 / incl. lics: 4.0778
# M416-208s_v2 - Standard_M416-208s_v2: 19.136000000000003 / excl. lics: 59.496 / incl. lics: 78.632
# M416s v2 - Standard_M416s_v2: 19.136000000000003 / excl. lics: 59.496 / incl. lics: 78.632
# M416-104s_v2 - Standard_M416-104s_v2: 19.136000000000003 / excl. lics: 59.496 / incl. lics: 78.632
# E64as v4 - Standard_E64as_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# E64a v4/E64as v4 - Standard_E64a_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# E8-2s v4 - Standard_E8-2s_v4: 0.368 / excl. lics: 0.608 / incl. lics: 0.976
# E4-2s v4 - Standard_E4-2s_v4: 0.184 / excl. lics: 0.304 / incl. lics: 0.488
# M32dms_v2 - M32dms_v2: 1.4720000000000013 / excl. lics: 8.604 / incl. lics: 10.076
# HB60-15rs - Standard_HB60-15rs: 2.7600000000000002 / excl. lics: 2.964 / incl. lics: 5.724
# NP10s - Standard_NP10s: 0.22999999999999998 / excl. lics: 1.3 / incl. lics: 1.53
# D16 v4 - Standard_D16_v4: 0.7359999999999999 / excl. lics: 0.92 / incl. lics: 1.656
# M8ms - Standard_M8ms: 0.5699000000000001 / excl. lics: 2.1511 / incl. lics: 2.721
# M8-4ms - Standard_M8-4ms: 0.5699000000000001 / excl. lics: 2.1511 / incl. lics: 2.721
# M8-2ms - Standard_M8-2ms: 0.5699000000000001 / excl. lics: 2.1511 / incl. lics: 2.721
# F72s v2 - Standard_F72s_v2: 3.17 / excl. lics: 3.492 / incl. lics: 6.662
# A2 v2 - Standard_A2_v2: 0.04300000000000001 / excl. lics: 0.087 / incl. lics: 0.13
# Unit price without Windows license could not be retrieved (Virtual Machines DSv2 Series Windows - DS12-2 v2)
# D64ds v4 - Standard_D64ds_v4: 2.944 / excl. lics: 4.352 / incl. lics: 7.296
# HB120rs v2 - Standard_HB120rs_v2: 5.52 / excl. lics: 4.68 / incl. lics: 10.2
# NV16as v4 - Standard_NV16as_v4: 0.736 / excl. lics: 1.165 / incl. lics: 1.901
# A5 - Standard_A5: 0.07 / excl. lics: 0.27 / incl. lics: 0.34
# DS2 v2 - Standard_DS2_v2: 0.13 / excl. lics: 0.136 / incl. lics: 0.266
# D2 v2/DS2 v2 - Standard_D2_v2: 0.13 / excl. lics: 0.136 / incl. lics: 0.266
# B20ms - Standard_B20ms: 0.08000000000000007 / excl. lics: 0.96 / incl. lics: 1.04
# E20s v4 - Standard_E20s_v4: 0.9199999999999999 / excl. lics: 1.52 / incl. lics: 2.44
# E16s v3 - Standard_E16s_v3: 0.736 / excl. lics: 1.28 / incl. lics: 2.016
# E16 v3/E16s v3 - Standard_E16_v3: 0.736 / excl. lics: 1.28 / incl. lics: 2.016
# E16-8s v3 - Standard_E16-8s_v3: 0.736 / excl. lics: 1.28 / incl. lics: 2.016
# E16-4s v3 - Standard_E16-4s_v3: 0.736 / excl. lics: 1.28 / incl. lics: 2.016
# E16-8ds v4 - Standard_E16-8ds_v4: 0.7360000000000002 / excl. lics: 1.384 / incl. lics: 2.12
# DC4s v2 - Standard_DC4s_v2: 0.18399999999999994 / excl. lics: 1.028 / incl. lics: 1.212
# A1 v2 - Standard_A1_v2: 0.020999999999999998 / excl. lics: 0.041 / incl. lics: 0.062
# M32ms_v2 - Standard_M32ms_v2: 1.4719999999999995 / excl. lics: 8.457 / incl. lics: 9.929
# NV32as v4 - Standard_NV32as_v4: 1.472 / excl. lics: 2.33 / incl. lics: 3.802
# DC8 v2 - Standard_DC8_v2: 0.3679999999999999 / excl. lics: 2.056 / incl. lics: 2.424
# E16d v4 - Standard_E16d_v4: 0.7360000000000002 / excl. lics: 1.384 / incl. lics: 2.12
# B16ms - Standard_B16ms: 0.06399999999999995 / excl. lics: 0.768 / incl. lics: 0.832
# PB6s - Standard_PB6s: 0.359 / excl. lics: 1.079 / incl. lics: 1.438
# M32ts - Standard_M32ts: 1.4719999999999995 / excl. lics: 3.248 / incl. lics: 4.72
# D8 v3/D8s v3 - Standard_D8_v3: 0.368 / excl. lics: 0.48 / incl. lics: 0.848
# D8s v3 - Standard_D8s_v3: 0.368 / excl. lics: 0.48 / incl. lics: 0.848
# E64-16ds v4 - Standard_E64-16ds_v4: 2.944000000000001 / excl. lics: 5.536 / incl. lics: 8.48
# B8ms - Standard_B8ms: 0.03199999999999997 / excl. lics: 0.384 / incl. lics: 0.416
# E64-16as_v4 - Standard_E64-16as_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# E16-4as_v4 - Standard_E16-4as_v4: 0.736 / excl. lics: 1.216 / incl. lics: 1.952
# A8 v2 - Standard_A8_v2: 0.19199999999999995 / excl. lics: 0.383 / incl. lics: 0.575
# D8d v4 - Standard_D8d_v4: 0.368 / excl. lics: 0.544 / incl. lics: 0.912
# D48as v4 - Standard_D48as_v4: 2.208 / excl. lics: 2.76 / incl. lics: 4.968
# D48a v4/D48as v4 - Standard_D48a_v4: 2.208 / excl. lics: 2.76 / incl. lics: 4.968
# GS2 - Standard_GS2: 0.14000000000000012 / excl. lics: 1.4 / incl. lics: 1.54
# G2/GS2 - Standard_G2: 0.14000000000000012 / excl. lics: 1.4 / incl. lics: 1.54
# NC16as T4 v3 - Standard_NC16as_T4_v3: 0.7360000000000002 / excl. lics: 1.505 / incl. lics: 2.241
# E64is v3 - Standard_E64is_v3: 2.944 / excl. lics: 4.376 / incl. lics: 7.32
# E64i v3/E64is v3 - Standard_E64i_v3: 2.944 / excl. lics: 4.376 / incl. lics: 7.32
# M64-32ms - Standard_M64-32ms: 4.564000000000002 / excl. lics: 14.472 / incl. lics: 19.036
# M64-16ms - Standard_M64-16ms: 4.564000000000002 / excl. lics: 14.472 / incl. lics: 19.036
# M64ms - Standard_M64ms: 4.564000000000002 / excl. lics: 14.472 / incl. lics: 19.036
# E8-2ds v4 - Standard_E8-2ds_v4: 0.3680000000000001 / excl. lics: 0.692 / incl. lics: 1.06
# M64m - : 4.564000000000002 / excl. lics: 14.472 / incl. lics: 19.036
# D3 v2/DS3 v2 - Standard_D3_v2: 0.261 / excl. lics: 0.272 / incl. lics: 0.533
# DS3 v2 - Standard_DS3_v2: 0.261 / excl. lics: 0.272 / incl. lics: 0.533
# D64 v4 - Standard_D64_v4: 2.9439999999999995 / excl. lics: 3.68 / incl. lics: 6.624
# A10 - Standard_A10: 0.345 / excl. lics: 0.897 / incl. lics: 1.242
# M128-32ms - Standard_M128-32ms: 9.125999999999998 / excl. lics: 37.3632 / incl. lics: 46.4892
# M128ms - Standard_M128ms: 9.125999999999998 / excl. lics: 37.3632 / incl. lics: 46.4892
# M128-64ms - Standard_M128-64ms: 9.125999999999998 / excl. lics: 37.3632 / incl. lics: 46.4892
# D2 v3/D2s v3 - Standard_D2_v3: 0.092 / excl. lics: 0.12 / incl. lics: 0.212
# D2s v3 - Standard_D2s_v3: 0.092 / excl. lics: 0.12 / incl. lics: 0.212
# M64ls - Standard_M64ls: 2.944 / excl. lics: 6.498 / incl. lics: 9.442
# E96-48as_v4 - Standard_E96-48as_v4: 4.4159999999999995 / excl. lics: 7.296 / incl. lics: 11.712
# E4s v4 - Standard_E4s_v4: 0.184 / excl. lics: 0.304 / incl. lics: 0.488
# NC64as T4 v3 - Standard_NC64as_T4_v3: 2.944 / excl. lics: 5.44 / incl. lics: 8.384
# ND40rs v2 - Standard_ND40rs_v2: 1.8399999999999999 / excl. lics: 27.526 / incl. lics: 29.366
# L16s - Standard_L16s: 0.7360000000000002 / excl. lics: 1.488 / incl. lics: 2.224
# DS13 - Standard_DS13: 0.2330000000000001 / excl. lics: 0.885 / incl. lics: 1.118
# D13/DS13 - Standard_D13: 0.2330000000000001 / excl. lics: 0.885 / incl. lics: 1.118
# GS1 - Standard_GS1: 0.07000000000000006 / excl. lics: 0.7 / incl. lics: 0.77
# G1/GS1 - Standard_G1: 0.07000000000000006 / excl. lics: 0.7 / incl. lics: 0.77
# M64s_v2 - Standard_M64s_v2: 2.944000000000001 / excl. lics: 9.042 / incl. lics: 11.986
# E64-32s v4 - Standard_E64-32s_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# E8-4as_v4 - Standard_E8-4as_v4: 0.368 / excl. lics: 0.608 / incl. lics: 0.976
# PB24s - Standard_PB24s: 1.4350000000000005 / excl. lics: 4.316 / incl. lics: 5.751
# NC24rs v2 - Standard_NC24rs_v2: 2.234 / excl. lics: 11.804 / incl. lics: 14.038
# B2s - Standard_B2s: 0.008 / excl. lics: 0.048 / incl. lics: 0.056
# D48ds v4 - Standard_D48ds_v4: 2.2080000000000006 / excl. lics: 3.264 / incl. lics: 5.472
# M128 - : 5.889000000000003 / excl. lics: 18.673 / incl. lics: 24.562
# F8s v2 - Standard_F8s_v2: 0.352 / excl. lics: 0.388 / incl. lics: 0.74
# E8 v4 - Standard_E8_v4: 0.368 / excl. lics: 0.608 / incl. lics: 0.976
# E20 v3/E20s v3 - Standard_E20_v3: 0.9199999999999999 / excl. lics: 1.6 / incl. lics: 2.52
# E20s v3 - Standard_E20s_v3: 0.9199999999999999 / excl. lics: 1.6 / incl. lics: 2.52
# A4m v2 - Standard_A4m_v2: 0.134 / excl. lics: 0.26 / incl. lics: 0.394
# M128ds_v2 - M128ds_v2: 5.888000000000002 / excl. lics: 18.676 / incl. lics: 24.564
# E8-4ds v4 - Standard_E8-4ds_v4: 0.3680000000000001 / excl. lics: 0.692 / incl. lics: 1.06
# E8-2as_v4 - Standard_E8-2as_v4: 0.368 / excl. lics: 0.608 / incl. lics: 0.976
# M192is_v2 - Standard_M192is_v2: 8.831999999999997 / excl. lics: 21.856 / incl. lics: 30.688
# E64s v4 - Standard_E64s_v4: 2.944 / excl. lics: 4.864 / incl. lics: 7.808
# E16-8s v4 - Standard_E16-8s_v4: 0.736 / excl. lics: 1.216 / incl. lics: 1.952
# M64 - : 2.944000000000001 / excl. lics: 9.337 / incl. lics: 12.281
# E4 v4 - Standard_E4_v4: 0.184 / excl. lics: 0.304 / incl. lics: 0.488
# D16ds v4 - Standard_D16ds_v4: 0.736 / excl. lics: 1.088 / incl. lics: 1.824
# L16s v2 - Standard_L16s_v2: 0.7360000000000002 / excl. lics: 1.488 / incl. lics: 2.224
# E48s v4 - Standard_E48s_v4: 2.2079999999999997 / excl. lics: 3.648 / incl. lics: 5.856
# E2d v4 - Standard_E2d_v4: 0.09200000000000003 / excl. lics: 0.173 / incl. lics: 0.265
# D2d v4 - Standard_D2d_v4: 0.092 / excl. lics: 0.136 / incl. lics: 0.228
# M32s - Standard_M32s: 1.4720000000000004 / excl. lics: 4.669 / incl. lics: 6.141
# DC2s - Standard_DC2s: 0.045999999999999985 / excl. lics: 0.257 / incl. lics: 0.303
# DS5 v2 - Standard_DS5_v2: 1.0439999999999998 / excl. lics: 1.087 / incl. lics: 2.131
# D5 v2/DS5 v2 - Standard_D5_v2: 1.0439999999999998 / excl. lics: 1.087 / incl. lics: 2.131
# B1ls - Standard_B1ls: 0.0046 / excl. lics: 0.006 / incl. lics: 0.0106
# A1 - Basic_A1: 0.008999999999999998 / excl. lics: 0.027 / incl. lics: 0.036
# E64-32ds v4 - Standard_E64-32ds_v4: 2.944000000000001 / excl. lics: 5.536 / incl. lics: 8.48
# B1s - Free - Standard_B1s: 0.0 / excl. lics: 0.0 / incl. lics: 0.0
